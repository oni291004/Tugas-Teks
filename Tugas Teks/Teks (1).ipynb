# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.diedit.com/pantun-penutup-presentasi/')
bs = BeautifulSoup(page.text, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
# ...

# %%
bs.find_all('p')
# Out:
# [<p class="main-title" itemprop="headline"> <a href="https://www.diedit.com/" rel="home">diedit.com</a></p>,
#  <p><strong><em><a href="https://www.diedit.com/wp-content/uploads/2021/05/Pantun-Penutup-Presentasi.jpg"><img alt="pantun penutup presentasi" class="aligncenter wp-image-18216 size-large" decoding="async" fetchpriority="high" height="853" loading="lazy" sizes="(max-width: 1024px) 100vw, 1024px" src="https://www.diedit.com/wp-content/uploads/2021/05/Pantun-Penutup-Presentasi-1024x853.jpg" srcset="https://www.diedit.com/wp-content/uploads/2021/05/Pantun-Penutup-Presentasi-1024x853.jpg 1024w, https://www.diedit.com/wp-content/uploads/2021/05/Pantun-Penutup-Presentasi-400x333.jpg 400w, https://www.diedit.com/wp-content/uploads/2021/05/Pantun-Penutup-Presentasi-768x640.jpg 768w, https://www.diedit.com/wp-content/uploads/2021/05/Pantun-Penutup-Presentasi.jpg 1200w" width="1024"/></a></em></strong></p>,
# ...

# %%
list_items_with_title = bs.find_all('p')
for li in list_items_with_title:
    print(li.text)
# Out:
#  diedit.com
#
# Presentasi adalah aktivitas bicara di hadapan orang banyak untuk menyampaikan suatu topik, informasi, data, fakta, dan opini, baik yang sifatnya hanya untuk informatif maupun juga bertujuan secara persuasif. Dalam dunia pendidikan, baik di sekolah maupun kampus, istilah presentasi sering diartikan sebagai kegiatan menyajikan laporan atau materi dari hasil tugas siswa/mahasiswa yang diberikan oleh guru atau dosen.
# Sementara itu, dalam dunia bisnis dan pemasaran, presentasi lebih sering bertujuan untuk membujuk, memberi informasi, atau meyakinkan calon konsumen, mitra bisnis, atau atasan terhadap ide/produk yang ingin ditawarkan. Sama seperti pidato, kegiatan presentasi juga sering dikaitkan dengan sesuatu yang serius dan formal.
# ...
